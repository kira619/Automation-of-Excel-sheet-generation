# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xlrd8

# %%
book1 = xlrd.open_workbook('VSAT.xlsx')
working_sheet_from_iocl = book1.sheet_by_index(2)
headings = working_sheet_from_iocl.row_values(0)

# %%
print(working_sheet_from_iocl.row_values(0))
# Out:
# ['VSAT ID', 'SAP PO ', 'RO SAP CODE', 'RO NAME', 'VSAT IP', 'SITE ADDRESS', 'DO NAME', 'INVOICE QTR', 'COMMISSIONING DATE', 'START DATE', 'END DATE', 'DAYS', 'SERVICE PROVIDING STATE', 'State of Service Receipt', 'H/W  RENTAL INVOICE NO', 'INVOICE DATE', 'HW Rate', 'H/W RENTAL', "Jan '20 uptime %", 'Deduction as per SLA', 'Payout %', "Feb '20 uptime %", 'Deduction as per SLA', 'Payout %', "March '20 uptime %", 'Deduction as per SLA', 'Payout %', 'Total Deductions for SLA', 'HW BASIC', 'HW GST', 'HW SLA Deduction inc GST', 'HW Calculated  Amount', 'HW Total From Vendor', 'HW Amount to be paid (Minimum of Calculated and Vendor', '', 'B/W  RENTAL INVOICE NO', 'INVOICE DATE', 'BW Rate / Month', 'B/W RENTAL', "Jan '20 uptime %", 'Deduction as per SLA', 'Payout %', "Feb '20 uptime %", 'Deduction as per SLA', 'Payout %', "March '20 uptime %", 'Deduction as per SLA', 'Payout %', 'Total Deductions for SLA', 'BW BASIC', 'BW GST', 'BW SLA Deduction inc GST', 'BW Calculated Amount', 'BW Total fr
# ...

# %%
df=pd.read_excel('VSAT.xlsx',sheet_name='Working Sheet from IOC')

# %%
df1 = df[['RO SAP CODE','RO NAME']]
df1
# Out:
#     RO SAP CODE                                 RO NAME
# 0        137990        BROADWAY-SERVICE-STATION--I-420-
# 1        273357         SWASTIK FUEL REFILL CENTRE(KSK)
# 2        140227                    STAR SERVICE STATION
# 3        292019                        GANPATI SQ.F/CEN
# 4        295158                       BASAK AUTOMOBILES
# 5        140175               KAMAKSHYA SERVICE STATION
# 6        267503     DHRITISHREE KISAN SEVA KENDRA [KSK]
# 7        246679         SABITA FUEL & AGRO AGENCY [KSK]
# 8        206671                AL KUDRAT-E-NISHAN (AOD)
# 9        208012           Baba Lokenath Service Station
# 10       138769       PAUL BROTHERS SERVICE STN (I-501)
# 11       138820           SARKAR SERVICE STATION(I-528)
# 12       190566                 CHANDIMATA AUTO SERVICE
# 13       273412     RANGDHAMALI KISAN SEVA KENDRA [KSK]
# 14       264848                             JANAGAN KSK
# 15       220588              MA TARA KISHAN SEVA KENDRA
# ...

# %%
df1['Payment Raise in XYZ quarter'] = df['HW BASIC'] + df['HW GST'] + df['BW BASIC'] + df['BW GST']
df1['SLA Deduction in XYZ quarter'] = df['HW SLA Deduction inc GST'] + df['BW SLA Deduction inc GST']
df1['Payment Made in XYZ quarter'] = df['HW Amount to be paid (Minimum of Calculated and Vendor'] + df['BW Amount to be paid (Minimum of Calculated and Vendor']
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df1.set_index('RO SAP CODE',inplace=True)
df1
# Out:
#                                             RO NAME  \
# RO SAP CODE
# 137990             BROADWAY-SERVICE-STATION--I-420-
# 273357              SWASTIK FUEL REFILL CENTRE(KSK)
# 140227                         STAR SERVICE STATION
# 292019                             GANPATI SQ.F/CEN
# 295158                            BASAK AUTOMOBILES
# 140175                    KAMAKSHYA SERVICE STATION
# 267503          DHRITISHREE KISAN SEVA KENDRA [KSK]
# 246679              SABITA FUEL & AGRO AGENCY [KSK]
# 206671                     AL KUDRAT-E-NISHAN (AOD)
# 208012                Baba Lokenath Service Station
# 138769            PAUL BROTHERS SERVICE STN (I-501)
# 138820                SARKAR SERVICE STATION(I-528)
# 190566                      CHANDIMATA AUTO SERVICE
# 273412          RANGDHAMALI KISAN SEVA KENDRA [KSK]
# 264848                                  JANAGAN KSK
# 220588                   MA TARA KISHAN SEVA KENDRA
# 295171                         MINA SERVICE STATION
# ...

# %%
df1.to_excel('AUTOMATED VSAT Report(1).xlsx',sheet_name='Automated Report')

# %%
df1
# Out:
#                                             RO NAME  \
# RO SAP CODE
# 137990             BROADWAY-SERVICE-STATION--I-420-
# 273357              SWASTIK FUEL REFILL CENTRE(KSK)
# 140227                         STAR SERVICE STATION
# 292019                             GANPATI SQ.F/CEN
# 295158                            BASAK AUTOMOBILES
# 140175                    KAMAKSHYA SERVICE STATION
# 267503          DHRITISHREE KISAN SEVA KENDRA [KSK]
# 246679              SABITA FUEL & AGRO AGENCY [KSK]
# 206671                     AL KUDRAT-E-NISHAN (AOD)
# 208012                Baba Lokenath Service Station
# 138769            PAUL BROTHERS SERVICE STN (I-501)
# 138820                SARKAR SERVICE STATION(I-528)
# 190566                      CHANDIMATA AUTO SERVICE
# 273412          RANGDHAMALI KISAN SEVA KENDRA [KSK]
# 264848                                  JANAGAN KSK
# 220588                   MA TARA KISHAN SEVA KENDRA
# 295171                         MINA SERVICE STATION
# ...
